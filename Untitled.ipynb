# %%
import pandas as pd

# %%
df = pd.read_csv('recon_data_raw.csv')

# %%
df.head()
# Out:
#    txn_ref_id sys_a_date  sys_a_amount_attribute_1  sys_a_amount_attribute_2  \
# 0    44516715   02/04/24                 20.000000                       1.4
# 1    34286015   07/07/24                116.699997                       1.4
# 2    90851690   07/05/24                 50.000000                       1.4
# 3    67286592   30/07/24                900.000000                       1.4
# 4    15780875   14/08/24               1120.000000                       1.4
#
#   sys_b_date  sys_b_amount_attribute_1  sys_b_amount_attribute_2 txn_type  \
# 0        NaN                       NaN                       NaN   payout
# 1        NaN                       NaN                       NaN   payout
# 2        NaN                       NaN                       NaN   payout
# 3        NaN                       NaN                       NaN   payout
# 4        NaN                       NaN                       NaN   payout
#
#   payment_method recon_status  \
# ...

# %%
type(df.iloc[0]['recon_sub_status'])
# Out:
# str

# %%
df['recon_sub_status'].head()
# Out:
# 0    {"amount":"Not Found-SysB","fee":"Not Found-Sy...
# 1    {"amount":"Not Found-SysB","fee":"Not Found-Sy...
# 2    {"amount":"Not Found-SysB","fee":"Not Found-Sy...
# 3    {"amount":"Not Found-SysB","fee":"Not Found-Sy...
# 4    {"amount":"Not Found-SysB","fee":"Not Found-Sy...
# Name: recon_sub_status, dtype: object

# %%
not_found_df = df[df['recon_sub_status'].str.contains("Not Found-SysB")]

# %%
not_found_df
# Out:
#      txn_ref_id sys_a_date  sys_a_amount_attribute_1  \
# 0      44516715   02/04/24                 20.000000
# 1      34286015   07/07/24                116.699997
# 2      90851690   07/05/24                 50.000000
# 3      67286592   30/07/24                900.000000
# 4      15780875   14/08/24               1120.000000
# ..          ...        ...                       ...
# 995    59465121   27/09/24                 12.000000
# 996    39694941   26/04/24                 14.000000
# 997    84236115   18/05/24                 40.000000
# 998    90817852   02/10/24                 30.000000
# 999    87922114   08/05/24                 40.000000
#
#      sys_a_amount_attribute_2 sys_b_date  sys_b_amount_attribute_1  \
# 0                         1.4        NaN                       NaN
# 1                         1.4        NaN                       NaN
# 2                         1.4        NaN                       NaN
# ...
